# %%
import PyPDF2
import re

# %%
reader = PyPDF2.PdfReader('./c1 psych.pdf')

# %%
# problem
reader.pages[1].extract_text().split('\n')[61]
# Out:
# 'Central Cape Gir 1:58.61  SO Kennedy Ringwald 7St. Francis Borg 1:59.16  SO Addison Pfeiffer 8'

# %%
def split_merged_line(line):
    """Splits a merged line into separate records when two swimmers' entries are combined."""
    time_pattern = r'(\d{1,2}:\d{2}\.\d{2}|\d{2}\.\d{2})'
    
    matches = list(re.finditer(time_pattern, line))

    if len(matches) <= 1:
        return [line] # ok

    split_match = re.search(r'(\d+)([A-Z])', line)

    if split_match:
        split_point = split_match.start(2)
        return [line[:split_point].strip(), line[split_point:].strip()]

    return [line]

# %%
split_merged_line('Central Cape Gir 1:58.61  SO Kennedy Ringwald 7St. Francis Borg 1:59.16  SO Addison Pfeiffer 8')
# Out:
# ['Central Cape Gir 1:58.61  SO Kennedy Ringwald 7',
#  'St. Francis Borg 1:59.16  SO Addison Pfeiffer 8']

# %%
output_file = 'psych_res_individual.txt'

with open(output_file, 'w') as f:
    event_name = ""

    for page in reader.pages:
        lines = page.extract_text().split('\n')

        for line in lines:
            if "Event" in line and "Girls" in line and "Yard" in line and "Relay" not in line: # process relays later
                new_name = re.sub(r'Event\s+\d+\s+\.+\((.+?)\)', r'\1', line).strip()
                new_name = " ".join(new_name.split())
                if new_name in event_name:
                    continue # reading header of a new page
                else:
                    event_name = new_name
                    f.write(f"EVENT NAME: {event_name}\n")
                continue

            possible_records = split_merged_line(line)
            for line in possible_records:
                match = re.match(r'(.+?)\s+(\d{1,2}:\d{2}\.\d{2}|\d{2}\.\d{2})\s+(\w{2})\s+([A-Za-z-]+(?:\s+[A-Za-z-]+)*)\s+(\d+)', line)

                if match:
                    school, time, grade, name, place = match.groups()
                    f.write(f"{school}\t{time}\t{grade}\t{name}\t{place}\n")

print(f"Extraction complete. Data saved to {output_file}")
# Out:
# Extraction complete. Data saved to psych_res_individual.txt

# %%
# another problem
reader.pages[0].extract_text().split('\n')[60]
# Out:
# '7) Claire Weber SO 8) India Browning SO1:59.35 Parkway Central 12'

# %%
def split_merged_relay_line(line):
    """Splits a merged relay team line where the next team's time and school name are attached."""
    split_match = re.search(r'([A-Za-z][A-Za-z])(\d{1,2}:\d{2}\.\d{2})', line)
    # split_match = re.search(r'(\d+)([A-Z])', line)

    if split_match:
        split_point = split_match.start(2)
        return [line[:split_point].strip(), line[split_point:].strip()]

    return [line] # ok

# %%
split_merged_relay_line('7) Claire Weber SO 8) India Browning SO1:59.35 Parkway Central 12')
# Out:
# ['7) Claire Weber SO 8) India Browning SO', '1:59.35 Parkway Central 12']

# %%
output_file = 'psych_res_relays.txt'

with open(output_file, 'w') as f:
    event_name = ""
    relay_mode = False
    current_relay = ""

    for page in reader.pages:
        lines = page.extract_text().split('\n')

        for i, line in enumerate(lines):
            if "Event" in line and "Girls" in line and "Yard" in line:
                new_name = re.sub(r'Event\s+\d+\s+\.+\((.+?)\)', r'\1', line).strip()
                new_name = " ".join(new_name.split())
                if new_name in event_name:
                    continue # reading header of a new page
                else:
                    event_name = new_name
                    f.write(f"EVENT NAME: {event_name}\n")
                    
                relay_mode = "Relay" in event_name
                continue
            
            if relay_mode:
                possible_records = split_merged_relay_line(line)
                for line in possible_records:
                    relay_match = re.match(r'(\d{1,2}:\d{2}\.\d{2})\s+(.+?)\s+(\d+)', line)
                    
                    if relay_match:
                        if current_relay:
                            f.write("\n".join(current_relay) + "\n")

                        seed_time, team, place = relay_match.groups()
                        current_relay = [f"{seed_time}\t{team}\t{place}"]
                        continue

                    swimmer_match = re.findall(r'(\d\))\s+([A-Za-z-]+(?:\s+[A-Za-z-]+)*)\s+([A-Z]{2})', line)
                    if swimmer_match and current_relay is not None:
                        for _, name, grade in swimmer_match:
                            current_relay.append(f"{name}\t{grade}")
                        continue

    if current_relay:
        f.write("\n".join(current_relay) + "\n")

print(f"Extraction complete. Data saved to {output_file}")
# Out:
# Extraction complete. Data saved to psych_res_relays.txt

# %%
# read individual events
i_events = {}
with open("./psych_res_individual.txt", "r") as times:
    lines = times.readlines()
    curr_evnt = ""
    
    for l in lines:
        if "EVENT NAME" in l:
            curr_evnt = l[12:len(l)-1]
            i_events[curr_evnt] = []
        else:
            as_list = l.split('\t')
            if len(as_list)==0:
                continue
            else:
                i_events[curr_evnt].append({
                    "team": as_list[0], "time": as_list[1], "grade": as_list[2], "name": as_list[3], 
                    "place": int(as_list[4])})

# %%
i_events
# Out:
# {'Event 2 Girls 200 Yard Freestyle': [{'team': "St. Joseph's Aca",
#    'time': '1:52.14',
#    'grade': 'JR',
#    'name': 'Anna-Grace Guenther',
#    'place': 1},
#   {'team': 'Pembroke Hill',
#    'time': '1:56.26',
#    'grade': 'SR',
#    'name': 'Kaya Alvegaard-Struble',
#    'place': 2},
#   {'team': 'Parkway West',
#    'time': '1:57.61',
#    'grade': 'JR',
#    'name': 'Sydney Matheny',
#    'place': 3},
#   {'team': 'Father Tolton Re',
#    'time': '1:57.65',
#    'grade': 'SO',
#    'name': 'Madison Arroyo',
#    'place': 4},
#   {'team': 'Webster Groves',
#    'time': '1:57.68',
#    'grade': 'FR',
#    'name': 'Quinn Porter',
#    'place': 5},
#   {'team': 'Villa Duchesne',
#    'time': '1:57.77',
#    'grade': 'SR',
#    'name': 'Grace Kraeger',
#    'place': 6},
#   {'team': 'Central Cape Gir',
#    'time': '1:58.61',
#    'grade': 'SO',
#    'name': 'Kennedy Ringwald',
#    'place': 7},
#   {'team': 'St. Francis Borg',
#    'time': '1:59.16',
#    'grade': 'SO',
#    'name': 'Addison Pfeiffer',
#    'place': 8},
#   {'team': 'Lutheran South',
#    'time': '1:59.42',
#    'grade': 'SO',
#    'name': 'Aubrey Yancey',
#    'place': 9},
#   {'team': "St. Teresa's Aca",
#    'time': '2:00.68',
#    'grade': 'SO',
#    'name': 'Polly Fendler',
#    'place': 10},
#   {'team': 'Clayton',
#    'time': '2:01.47',
#    'grade': 'SR',
#    'name': 'Anna McAndrew',
#    'place': 11},
#   {'team': 'Ladue Horton Wat',
#    'time': '2:01.63',
#    'grade': 'SR',
#    'name': 'Sylvia Hanes',
#    'place': 12},
#   {'team': 'Father Tolton Re',
#    'time': '2:02.02',
#    'grade': 'FR',
#    'name': 'Kayla Perrone',
#    'place': 13},
#   {'team': 'Father Tolton Re',
#    'time': '2:02.72',
#    'grade': 'FR',
#    'name': 'Paige Boomer',
#    'place': 14},
#   {'team': 'Visitation Acade',
#    'time': '2:02.86',
#    'grade': 'JR',
#    'name': 'Madison Seabaugh',
#    'place': 15},
#   {'team': "St. Joseph's Aca",
#    'time': '2:03.59',
#    'grade': 'FR',
#    'name': 'Erin Jones',
#    'place': 16},
#   {'team': 'Parkway Central',
#    'time': '2:05.23',
#    'grade': 'SO',
#    'name': 'Gabrielle Salmans',
#    'place': 17},
#   {'team': 'Visitation Acade',
#    'time': '2:05.55',
#    'grade': 'SO',
#    'name': 'Abigail Conrardy',
#    'place': 18},
#   {'team': 'New Covenant Aca',
#    'time': '2:06.36',
#    'grade': 'SR',
#    'name': 'Natalie Block',
#    'place': 19},
#   {'team': 'Notre Dame de Si',
#    'time': '2:06.42',
#    'grade': 'JR',
#    'name': 'Burke Sutton',
#    'place': 20},
#   {'team': 'Ft. Zumwalt East',
#    'time': '2:07.59',
#    'grade': 'JR',
#    'name': 'Maya West',
#    'place': 21},
#   {'team': 'Lutheran St. Cha',
#    'time': '2:07.65',
#    'grade': 'FR',
#    'name': 'Avery Eastman',
#    'place': 22},
#   {'team': 'Logan-Rogersvill',
#    'time': '2:07.67',
#    'grade': 'SR',
#    'name': 'Allison Hazen',
#    'place': 23},
#   {'team': 'Parkway Central',
#    'time': '2:07.72',
#    'grade': 'SO',
#    'name': 'Victoria Knolhoff',
#    'place': 24},
#   {'team': 'West Plains',
#    'time': '2:07.88',
#    'grade': 'FR',
#    'name': 'Gwendolyn Fiorino',
#    'place': 25},
#   {'team': 'Carl Junction',
#    'time': '2:08.48',
#    'grade': 'JR',
#    'name': 'Lilian Schultz',
#    'place': 26},
#   {'team': 'Grain Valley',
#    'time': '2:08.61',
#    'grade': 'JR',
#    'name': 'Katelyn Epple',
#    'place': 27},
#   {'team': 'Incarnate Word A',
#    'time': '2:09.01',
#    'grade': 'SO',
#    'name': 'Morgan Parkerson',
#    'place': 28},
#   {'team': 'Webb City',
#    'time': '2:09.21',
#    'grade': 'JR',
#    'name': 'Norah Klosterman',
#    'place': 29},
#   {'team': "St. Joseph's Aca",
#    'time': '2:10.23',
#    'grade': 'SO',
#    'name': 'Madison Elmore',
#    'place': 30},
#   {'team': 'Parkway North',
#    'time': '2:10.40',
#    'grade': 'SR',
#    'name': 'Athena DeKinder',
#    'place': 31},
#   {'team': 'Glendale',
#    'time': '2:10.53',
#    'grade': 'SR',
#    'name': 'Sarah Schneider',
#    'place': 32}],
#  'Event 3 Girls 200 Yard IM': [{'team': 'Villa Duchesne',
#    'time': '2:05.19',
#    'grade': 'JR',
#    'name': 'Charlotte Brown',
#    'place': 1},
#   {'team': 'Pembroke Hill',
#    'time': '2:06.82',
#    'grade': 'JR',
#    'name': 'Helena Tietjen',
#    'place': 2},
#   {'team': 'Clayton',
#    'time': '2:09.13',
#    'grade': 'SR',
#    'name': 'Emma Louise Welch',
#    'place': 3},
#   {'team': 'Louisiana',
#    'time': '2:09.96',
#    'grade': 'JR',
#    'name': 'Gracey MacLaughlin',
#    'place': 4},
#   {'team': 'Ursuline Academy',
#    'time': '2:10.34',
#    'grade': 'SO',
#    'name': 'Kennedy Chrun',
#    'place': 5},
#   {'team': 'Father Tolton Re',
#    'time': '2:11.22',
#    'grade': 'SO',
#    'name': 'Sophia Stoops',
#    'place': 6},
#   {'team': 'Mehlville',
#    'time': '2:11.59',
#    'grade': 'SO',
#    'name': 'Lily Kohler',
#    'place': 7},
#   {'team': "St. Joseph's Aca",
#    'time': '2:13.55',
#    'grade': 'JR',
#    'name': 'Vienna Schindler',
#    'place': 8},
#   {'team': 'Grain Valley',
#    'time': '2:14.87',
#    'grade': 'JR',
#    'name': 'Elizabeth Martin',
#    'place': 9},
#   {'team': 'John Burroughs',
#    'time': '2:15.21',
#    'grade': 'SR',
#    'name': 'Jacqueline Hu',
#    'place': 10},
#   {'team': 'St. Charles West',
#    'time': '2:15.35',
#    'grade': 'SR',
#    'name': 'Stella Garrison',
#    'place': 11},
#   {'team': 'St. Pius X (Kans',
#    'time': '2:16.29',
#    'grade': 'SR',
#    'name': 'Alynah Tran',
#    'place': 12},
#   {'team': 'Clayton',
#    'time': '2:19.96',
#    'grade': 'SO',
#    'name': 'Ema Stojicevic',
#    'place': 13},
#   {'team': 'John Burroughs',
#    'time': '2:20.06',
#    'grade': 'FR',
#    'name': 'Alicia Williams',
#    'place': 14},
#   {'team': 'Principia',
#    'time': '2:21.34',
#    'grade': 'FR',
#    'name': 'Sarah Lamb',
#    'place': 15},
#   {'team': 'Thomas Jefferson',
#    'time': '2:21.58',
#    'grade': 'SO',
#    'name': 'Katerina Pruitt',
#    'place': 16},
#   {'team': 'Monett',
#    'time': '2:22.00',
#    'grade': 'FR',
#    'name': 'Isabell Coffey',
#    'place': 17},
#   {'team': 'West Plains',
#    'time': '2:22.03',
#    'grade': 'JR',
#    'name': 'Penelope Autry',
#    'place': 18},
#   {'team': 'Villa Duchesne',
#    'time': '2:22.15',
#    'grade': 'JR',
#    'name': 'Audrey Qureshi',
#    'place': 19},
#   {'team': 'Monett',
#    'time': '2:22.50',
#    'grade': 'SO',
#    'name': 'Emelia Rosebaugh',
#    'place': 20},
#   {'team': 'St. Dominic',
#    'time': '2:22.72',
#    'grade': 'JR',
#    'name': 'Amelia Martin',
#    'place': 21},
#   {'team': 'Webb City',
#    'time': '2:22.83',
#    'grade': 'SR',
#    'name': 'Camryn Klosterman',
#    'place': 22},
#   {'team': 'Hannibal',
#    'time': '2:23.02',
#    'grade': 'JR',
#    'name': 'Olivia Johnson',
#    'place': 23},
#   {'team': 'Father Tolton Re',
#    'time': '2:23.31',
#    'grade': 'FR',
#    'name': 'Paige Boomer',
#    'place': 24},
#   {'team': "St. Joseph's Aca",
#    'time': '2:23.63',
#    'grade': 'SR',
#    'name': 'Macie DiGuiseppe',
#    'place': 25},
#   {'team': 'John Burroughs',
#    'time': '2:23.64',
#    'grade': 'SO',
#    'name': 'Sienna Kelley',
#    'place': 26},
#   {'team': 'Thomas Jefferson',
#    'time': '2:25.30',
#    'grade': 'SR',
#    'name': 'Natalie Carroll',
#    'place': 27},
#   {'team': 'Battle',
#    'time': '2:25.67',
#    'grade': 'SO',
#    'name': 'Lila Morris',
#    'place': 28},
#   {'team': 'Savannah',
#    'time': '2:26.06',
#    'grade': 'JR',
#    'name': 'Reece Gould',
#    'place': 29},
#   {'team': 'Hannibal',
#    'time': '2:26.23',
#    'grade': 'SO',
#    'name': 'Scarlett Sternke',
#    'place': 30},
#   {'team': 'Republic',
#    'time': '2:26.31',
#    'grade': 'FR',
#    'name': 'Elise Replogle',
#    'place': 31},
#   {'team': 'Carl Junction',
#    'time': '2:26.36',
#    'grade': 'SO',
#    'name': 'Elsa Dogotch',
#    'place': 32}],
#  'Event 4 Girls 50 Yard Freestyle': [{'team': 'Central Cape Gir',
#    'time': '23.54',
#    'grade': 'FR',
#    'name': 'Karsynne McAlister',
#    'place': 1},
#   {'team': 'Central Cape Gir',
#    'time': '24.09',
#    'grade': 'SR',
#    'name': 'Sydney Ringwald',
#    'place': 2},
#   {'team': 'St. Michael the',
#    'time': '24.14',
#    'grade': 'SO',
#    'name': 'Avery Frick',
#    'place': 3},
#   {'team': 'Notre Dame de Si',
#    'time': '24.42',
#    'grade': 'SO',
#    'name': 'Finley Glennon',
#    'place': 4},
#   {'team': 'West Plains',
#    'time': '24.89',
#    'grade': 'JR',
#    'name': 'Roslyn Fiorino',
#    'place': 5},
#   {'team': "St. Teresa's Aca",
#    'time': '24.92',
#    'grade': 'JR',
#    'name': 'Ava Fugate',
#    'place': 6},
#   {'team': 'Carl Junction',
#    'time': '25.03',
#    'grade': 'SR',
#    'name': 'Elyanna Dogotch',
#    'place': 7},
#   {'team': 'Parkway Central',
#    'time': '25.04',
#    'grade': 'JR',
#    'name': 'Cecilia Tremont',
#    'place': 8},
#   {'team': "St. Joseph's Aca",
#    'time': '25.13',
#    'grade': 'SO',
#    'name': 'Claire Chumley',
#    'place': 9},
#   {'team': 'Central Cape Gir',
#    'time': '25.18',
#    'grade': 'SR',
#    'name': 'Isabella Pattengill',
#    'place': 10},
#   {'team': 'Grain Valley',
#    'time': '25.28',
#    'grade': 'JR',
#    'name': 'Kalli Beard',
#    'place': 11},
#   {'team': 'Parkway Central',
#    'time': '25.43',
#    'grade': 'SO',
#    'name': 'Kenadie Johnson',
#    'place': 12},
#   {'team': 'Rockwood Summit',
#    'time': '25.44',
#    'grade': 'JR',
#    'name': 'Breanna Wilkinson',
#    'place': 13},
#   {'team': "St. Joseph's Aca",
#    'time': '25.46',
#    'grade': 'SR',
#    'name': 'Eleanor Green',
#    'place': 14},
#   {'team': 'Notre Dame de Si',
#    'time': '25.49',
#    'grade': 'FR',
#    'name': 'Kennedy Roberts',
#    'place': 15},
#   {'team': 'Central (Springf',
#    'time': '25.52',
#    'grade': 'SO',
#    'name': 'Edith Ferguson',
#    'place': 16},
#   {'team': 'Pembroke Hill',
#    'time': '25.65',
#    'grade': 'JR',
#    'name': 'Kayla Ilardi',
#    'place': 17},
#   {'team': "St. Teresa's Aca",
#    'time': '25.71',
#    'grade': 'SO',
#    'name': 'Josephine Schloegel',
#    'place': 18},
#   {'team': 'Ft. Zumwalt Sout',
#    'time': '25.75',
#    'grade': 'SR',
#    'name': 'Madalynn Lady',
#    'place': 19},
#   {'team': 'Louisiana',
#    'time': '25.78',
#    'grade': 'SO',
#    'name': 'Storie Talbert',
#    'place': 20},
#   {'team': 'St. Francis Borg',
#    'time': '25.78',
#    'grade': 'SR',
#    'name': 'Sophia Sullentrup',
#    'place': 21},
#   {'team': 'Clayton',
#    'time': '25.80',
#    'grade': 'JR',
#    'name': 'Samantha Cohen',
#    'place': 22},
#   {'team': 'Lutheran St. Cha',
#    'time': '25.86',
#    'grade': 'SR',
#    'name': 'Sarah Wallace',
#    'place': 23},
#   {'team': 'Clayton',
#    'time': '25.88',
#    'grade': 'SR',
#    'name': 'Ella Caroline Welch',
#    'place': 24},
#   {'team': 'Ladue Horton Wat',
#    'time': '25.97',
#    'grade': 'SR',
#    'name': 'Margaret Willmann',
#    'place': 25},
#   {'team': "St. Teresa's Aca",
#    'time': '26.01',
#    'grade': 'FR',
#    'name': 'Katherine Campbell',
#    'place': 26},
#   {'team': 'Poplar Bluff',
#    'time': '26.04',
#    'grade': 'JR',
#    'name': 'Keira Willis',
#    'place': 27},
#   {'team': 'Mehlville',
#    'time': '26.10',
#    'grade': 'SR',
#    'name': 'Allison Miller',
#    'place': 28},
#   {'team': 'Webb City',
#    'time': '26.32',
#    'grade': 'SR',
#    'name': 'Alix Davis',
#    'place': 29},
#   {'team': 'Smithville',
#    'time': '26.34',
#    'grade': 'SR',
#    'name': 'Ally Pottebaum',
#    'place': 30},
#   {'team': 'Summit Christian',
#    'time': '26.43',
#    'grade': 'FR',
#    'name': 'Jillian Markley',
#    'place': 31},
#   {'team': 'Nevada',
#    'time': '26.50',
#    'grade': 'FR',
#    'name': 'Alatna Snyder',
#    'place': 32}],
#  'Event 6 Girls 100 Yard Butterfly': [{'team': 'Pembroke Hill',
#    'time': '55.31',
#    'grade': 'JR',
#    'name': 'Helena Tietjen',
#    'place': 1},
#   {'team': 'Visitation Acade',
#    'time': '57.52',
#    'grade': 'SR',
#    'name': 'Ashlyn Canale',
#    'place': 2},
#   {'team': 'Parkway Central',
#    'time': '57.71',
#    'grade': 'JR',
#    'name': 'Reese Anderson',
#    'place': 3},
#   {'team': "St. Joseph's Aca",
#    'time': '58.39',
#    'grade': 'FR',
#    'name': 'Payton Robic',
#    'place': 4},
#   {'team': 'Parkway Central',
#    'time': '59.02',
#    'grade': 'JR',
#    'name': 'Serena Huang',
#    'place': 5},
#   {'team': 'Webster Groves',
#    'time': '59.13',
#    'grade': 'FR',
#    'name': 'Quinn Porter',
#    'place': 6},
#   {'team': 'Visitation Acade',
#    'time': '59.21',
#    'grade': 'SO',
#    'name': 'Madelyn Mug',
#    'place': 7},
#   {'team': 'Lutheran South',
#    'time': '59.24',
#    'grade': 'SO',
#    'name': 'Aubrey Yancey',
#    'place': 8},
#   {'team': "St. Teresa's Aca",
#    'time': '59.29',
#    'grade': 'JR',
#    'name': 'Ava Fugate',
#    'place': 9},
#   {'team': 'Rockwood Summit',
#    'time': '59.43',
#    'grade': 'JR',
#    'name': 'Breanna Wilkinson',
#    'place': 10},
#   {'team': 'Grain Valley',
#    'time': '1:00.96',
#    'grade': 'JR',
#    'name': 'Kalli Beard',
#    'place': 11},
#   {'team': 'Ft. Zumwalt Sout',
#    'time': '1:01.13',
#    'grade': 'SR',
#    'name': 'Madalynn Lady',
#    'place': 12},
#   {'team': "St. Joseph's Aca",
#    'time': '1:01.71',
#    'grade': 'FR',
#    'name': 'Maddie Riley',
#    'place': 13},
#   {'team': 'Ladue Horton Wat',
#    'time': '1:02.45',
#    'grade': 'SR',
#    'name': 'Sylvia Hanes',
#    'place': 14},
#   {'team': 'Logan-Rogersvill',
#    'time': '1:02.93',
#    'grade': 'SR',
#    'name': 'Mya Kite',
#    'place': 15},
#   {'team': 'Kearney',
#    'time': '1:03.44',
#    'grade': 'FR',
#    'name': 'Kaylie Gerber',
#    'place': 16},
#   {'team': 'Ursuline Academy',
#    'time': '1:03.57',
#    'grade': 'JR',
#    'name': 'Jessica Lee',
#    'place': 17},
#   {'team': 'Platte County',
#    'time': '1:04.04',
#    'grade': 'JR',
#    'name': 'Ashleigh Cruce',
#    'place': 18},
#   {'team': "St. Joseph's Aca",
#    'time': '1:04.12',
#    'grade': 'FR',
#    'name': 'Claire Petri',
#    'place': 19},
#   {'team': 'Notre Dame de Si',
#    'time': '1:04.30',
#    'grade': 'SR',
#    'name': 'Maeve Glennon',
#    'place': 20},
#   {'team': 'Thomas Jefferson',
#    'time': '1:04.41',
#    'grade': 'SR',
#    'name': 'Natalie Carroll',
#    'place': 21},
#   {'team': 'Parkway West',
#    'time': '1:04.43',
#    'grade': 'SO',
#    'name': 'Brynna Vogler',
#    'place': 22},
#   {'team': 'Clayton',
#    'time': '1:04.91',
#    'grade': 'FR',
#    'name': 'Lilah Orlando',
#    'place': 23},
#   {'team': 'West Plains',
#    'time': '1:04.97',
#    'grade': 'JR',
#    'name': 'Penelope Autry',
#    'place': 24},
#   {'team': 'Central (Springf',
#    'time': '1:05.00',
#    'grade': 'SR',
#    'name': 'Naomi Meng',
#    'place': 25},
#   {'team': 'Lutheran St. Cha',
#    'time': '1:05.28',
#    'grade': 'JR',
#    'name': 'Sarah Gross',
#    'place': 26},
#   {'team': 'Rockwood Summit',
#    'time': '1:05.66',
#    'grade': 'FR',
#    'name': 'Ryan Weber',
#    'place': 27},
#   {'team': 'Villa Duchesne',
#    'time': '1:05.88',
#    'grade': 'SO',
#    'name': 'Jane Hill',
#    'place': 28},
#   {'team': 'Smithville',
#    'time': '1:06.57',
#    'grade': 'SR',
#    'name': 'Ally Pottebaum',
#    'place': 29},
#   {'team': "St. Joseph's Aca",
#    'time': '1:06.94',
#    'grade': 'FR',
#    'name': 'Cece Potthast',
#    'place': 30},
#   {'team': 'St. Michael the',
#    'time': '1:06.99',
#    'grade': 'FR',
#    'name': 'Lyla Ventimiglia',
#    'place': 31},
#   {'team': 'Webster Groves',
#    'time': '1:07.04',
#    'grade': 'FR',
#    'name': 'Willa Shank',
#    'place': 32}],
#  'Event 7 Girls 100 Yard Freestyle': [{'team': 'Central Cape Gir',
#    'time': '52.20',
#    'grade': 'SR',
#    'name': 'Sydney Ringwald',
#    'place': 1},
#   {'team': "St. Joseph's Aca",
#    'time': '52.80',
#    'grade': 'JR',
#    'name': 'Avery Cunneen',
#    'place': 2},
#   {'team': 'St. Michael the',
#    'time': '53.19',
#    'grade': 'SO',
#    'name': 'Avery Frick',
#    'place': 3},
#   {'team': 'West Plains',
#    'time': '53.75',
#    'grade': 'JR',
#    'name': 'Roslyn Fiorino',
#    'place': 4},
#   {'team': "St. Joseph's Aca",
#    'time': '54.15',
#    'grade': 'SR',
#    'name': 'Eleanor Green',
#    'place': 5},
#   {'team': 'Parkway Central',
#    'time': '54.71',
#    'grade': 'JR',
#    'name': 'Cecilia Tremont',
#    'place': 6},
#   {'team': 'Carl Junction',
#    'time': '55.12',
#    'grade': 'SR',
#    'name': 'Elyanna Dogotch',
#    'place': 7},
#   {'team': 'John Burroughs',
#    'time': '55.14',
#    'grade': 'JR',
#    'name': 'Madeleine Williams',
#    'place': 8},
#   {'team': 'Father Tolton Re',
#    'time': '55.34',
#    'grade': 'FR',
#    'name': 'Kayla Perrone',
#    'place': 9},
#   {'team': 'Central Cape Gir',
#    'time': '55.67',
#    'grade': 'SR',
#    'name': 'Isabella Pattengill',
#    'place': 10},
#   {'team': 'West Plains',
#    'time': '55.78',
#    'grade': 'SR',
#    'name': 'Evie Niesen',
#    'place': 11},
#   {'team': 'Lutheran St. Cha',
#    'time': '56.06',
#    'grade': 'SR',
#    'name': 'Sarah Wallace',
#    'place': 12},
#   {'team': 'Parkway North',
#    'time': '56.43',
#    'grade': 'JR',
#    'name': 'Mary Wolf-Slinkard',
#    'place': 13},
#   {'team': 'Clayton',
#    'time': '56.46',
#    'grade': 'JR',
#    'name': 'Samantha Cohen',
#    'place': 14},
#   {'team': 'Ladue Horton Wat',
#    'time': '56.54',
#    'grade': 'SR',
#    'name': 'Margaret Willmann',
#    'place': 15},
#   {'team': 'Parkway Central',
#    'time': '56.89',
#    'grade': 'SO',
#    'name': 'Gabrielle Salmans',
#    'place': 16},
#   {'team': 'Pembroke Hill',
#    'time': '56.94',
#    'grade': 'JR',
#    'name': 'Kayla Ilardi',
#    'place': 17},
#   {'team': "St. Teresa's Aca",
#    'time': '56.96',
#    'grade': 'FR',
#    'name': 'Katherine Campbell',
#    'place': 18},
#   {'team': 'Visitation Acade',
#    'time': '57.27',
#    'grade': 'SO',
#    'name': 'Abigail Conrardy',
#    'place': 19},
#   {'team': 'Louisiana',
#    'time': '57.34',
#    'grade': 'SO',
#    'name': 'Storie Talbert',
#    'place': 20},
#   {'team': 'St. Francis Borg',
#    'time': '57.43',
#    'grade': 'SR',
#    'name': 'Sophia Sullentrup',
#    'place': 21},
#   {'team': "St. Teresa's Aca",
#    'time': '57.72',
#    'grade': 'SO',
#    'name': 'Josephine Schloegel',
#    'place': 22},
#   {'team': 'Nevada',
#    'time': '58.00',
#    'grade': 'FR',
#    'name': 'Alatna Snyder',
#    'place': 23},
#   {'team': 'Grain Valley',
#    'time': '58.17',
#    'grade': 'JR',
#    'name': 'Katelyn Epple',
#    'place': 24},
#   {'team': "St. Joseph's Aca",
#    'time': '58.24',
#    'grade': 'SO',
#    'name': 'Jordyn Hamrah',
#    'place': 25},
#   {'team': 'Central (Springf',
#    'time': '58.35',
#    'grade': 'SR',
#    'name': 'Fiona Lu',
#    'place': 26},
#   {'team': 'Rockwood Summit',
#    'time': '58.52',
#    'grade': 'SR',
#    'name': 'Lillian Maginn',
#    'place': 27},
#   {'team': 'Glendale',
#    'time': '58.54',
#    'grade': 'SR',
#    'name': 'Mollie Jane Brawner',
#    'place': 28},
#   {'team': 'Parkway West',
#    'time': '58.94',
#    'grade': 'JR',
#    'name': 'Audrianna VanKirk',
#    'place': 29},
#   {'team': 'Poplar Bluff',
#    'time': '59.22',
#    'grade': 'JR',
#    'name': 'Keira Willis',
#    'place': 30},
#   {'team': 'Parkway Central',
#    'time': '59.27',
#    'grade': 'FR',
#    'name': 'Gianna Pearson',
#    'place': 31},
#   {'team': "St. Teresa's Aca",
#    'time': '59.32',
#    'grade': 'FR',
#    'name': 'Ella Messner',
#    'place': 32}],
#  'Event 8 Girls 500 Yard Freestyle': [{'team': "St. Joseph's Aca",
#    'time': '4:59.70',
#    'grade': 'JR',
#    'name': 'Anna-Grace Guenther',
#    'place': 1},
#   {'team': 'Clayton',
#    'time': '5:10.96',
#    'grade': 'SO',
#    'name': 'Ema Stojicevic',
#    'place': 2},
#   {'team': 'Parkway Central',
#    'time': '5:12.36',
#    'grade': 'JR',
#    'name': 'Reese Anderson',
#    'place': 3},
#   {'team': 'Father Tolton Re',
#    'time': '5:14.20',
#    'grade': 'SO',
#    'name': 'Sophia Stoops',
#    'place': 4},
#   {'team': 'Parkway West',
#    'time': '5:16.14',
#    'grade': 'JR',
#    'name': 'Sydney Matheny',
#    'place': 5},
#   {'team': 'Mehlville',
#    'time': '5:16.33',
#    'grade': 'SO',
#    'name': 'Lily Kohler',
#    'place': 6},
#   {'team': 'Father Tolton Re',
#    'time': '5:19.87',
#    'grade': 'SO',
#    'name': 'Madison Arroyo',
#    'place': 7},
#   {'team': 'Central Cape Gir',
#    'time': '5:20.59',
#    'grade': 'SO',
#    'name': 'Kennedy Ringwald',
#    'place': 8},
#   {'team': 'Louisiana',
#    'time': '5:21.84',
#    'grade': 'JR',
#    'name': 'Gracey MacLaughlin',
#    'place': 9},
#   {'team': 'St. Francis Borg',
#    'time': '5:26.07',
#    'grade': 'SO',
#    'name': 'Addison Pfeiffer',
#    'place': 10},
#   {'team': 'Notre Dame de Si',
#    'time': '5:29.23',
#    'grade': 'JR',
#    'name': 'Burke Sutton',
#    'place': 11},
#   {'team': 'Clayton',
#    'time': '5:29.27',
#    'grade': 'SR',
#    'name': 'Anna McAndrew',
#    'place': 12},
#   {'team': "St. Joseph's Aca",
#    'time': '5:29.67',
#    'grade': 'FR',
#    'name': 'Erin Jones',
#    'place': 13},
#   {'team': "St. Teresa's Aca",
#    'time': '5:30.53',
#    'grade': 'SO',
#    'name': 'Polly Fendler',
#    'place': 14},
#   {'team': 'Grain Valley',
#    'time': '5:31.43',
#    'grade': 'JR',
#    'name': 'Elizabeth Martin',
#    'place': 15},
#   {'team': 'Central (Springf',
#    'time': '5:34.46',
#    'grade': 'SO',
#    'name': 'Edith Ferguson',
#    'place': 16},
#   {'team': 'Thomas Jefferson',
#    'time': '5:37.53',
#    'grade': 'SO',
#    'name': 'Katerina Pruitt',
#    'place': 17},
#   {'team': 'Mehlville',
#    'time': '5:38.37',
#    'grade': 'SR',
#    'name': 'Allison Miller',
#    'place': 18},
#   {'team': 'Ursuline Academy',
#    'time': '5:39.62',
#    'grade': 'JR',
#    'name': 'Jessica Lee',
#    'place': 19},
#   {'team': 'Visitation Acade',
#    'time': '5:40.69',
#    'grade': 'JR',
#    'name': 'Madison Seabaugh',
#    'place': 20},
#   {'team': 'Carl Junction',
#    'time': '5:41.98',
#    'grade': 'JR',
#    'name': 'Lilian Schultz',
#    'place': 21},
#   {'team': 'Incarnate Word A',
#    'time': '5:42.28',
#    'grade': 'SO',
#    'name': 'Morgan Parkerson',
#    'place': 22},
#   {'team': 'Webb City',
#    'time': '5:42.49',
#    'grade': 'JR',
#    'name': 'Norah Klosterman',
#    'place': 23},
#   {'team': 'Rockwood Summit',
#    'time': '5:42.58',
#    'grade': 'FR',
#    'name': 'Ryan Weber',
#    'place': 24},
#   {'team': 'Webb City',
#    'time': '5:43.32',
#    'grade': 'FR',
#    'name': 'Aspen Ritchie',
#    'place': 25},
#   {'team': 'Parkway West',
#    'time': '5:46.48',
#    'grade': 'SO',
#    'name': 'Isabella Lamb',
#    'place': 26},
#   {'team': "St. Joseph's Aca",
#    'time': '5:46.78',
#    'grade': 'SO',
#    'name': 'Madison Elmore',
#    'place': 27},
#   {'team': 'John Burroughs',
#    'time': '5:46.83',
#    'grade': 'SO',
#    'name': 'Sienna Kelley',
#    'place': 28},
#   {'team': 'Webster Groves',
#    'time': '5:47.21',
#    'grade': 'SO',
#    'name': 'Sophia Warnick',
#    'place': 29},
#   {'team': 'Hannibal',
#    'time': '5:47.42',
#    'grade': 'FR',
#    'name': 'Brooke Hess',
#    'place': 30},
#   {'team': 'Lutheran St. Cha',
#    'time': '5:48.32',
#    'grade': 'FR',
#    'name': 'Avery Eastman',
#    'place': 31},
#   {'team': 'Monett',
#    'time': '5:51.06',
#    'grade': 'FR',
#    'name': 'Olivia Earnest',
#    'place': 32}],
#  'Event 10 Girls 100 Yard Backstroke': [{'team': "St. Joseph's Aca",
#    'time': '55.70',
#    'grade': 'JR',
#    'name': 'Avery Cunneen',
#    'place': 1},
#   {'team': "St. Joseph's Aca",
#    'time': '56.84',
#    'grade': 'SO',
#    'name': 'Claire Chumley',
#    'place': 2},
#   {'team': 'Villa Duchesne',
#    'time': '57.24',
#    'grade': 'SR',
#    'name': 'Grace Kraeger',
#    'place': 3},
#   {'team': 'Clayton',
#    'time': '58.53',
#    'grade': 'SR',
#    'name': 'Emma Louise Welch',
#    'place': 4},
#   {'team': 'Pembroke Hill',
#    'time': '58.96',
#    'grade': 'SR',
#    'name': 'Kaya Alvegaard-Struble',
#    'place': 5},
#   {'team': 'Visitation Acade',
#    'time': '59.38',
#    'grade': 'SO',
#    'name': 'Madelyn Mug',
#    'place': 6},
#   {'team': 'Clayton',
#    'time': '1:00.05',
#    'grade': 'SR',
#    'name': 'Ella Caroline Welch',
#    'place': 7},
#   {'team': 'Central Cape Gir',
#    'time': '1:00.19',
#    'grade': 'FR',
#    'name': 'Karsynne McAlister',
#    'place': 8},
#   {'team': "St. Joseph's Aca",
#    'time': '1:01.36',
#    'grade': 'FR',
#    'name': 'Maddie Riley',
#    'place': 9},
#   {'team': 'Notre Dame de Si',
#    'time': '1:02.18',
#    'grade': 'FR',
#    'name': 'Kennedy Roberts',
#    'place': 10},
#   {'team': 'Monett',
#    'time': '1:02.50',
#    'grade': 'FR',
#    'name': 'Isabell Coffey',
#    'place': 11},
#   {'team': 'Villa Duchesne',
#    'time': '1:02.54',
#    'grade': 'SO',
#    'name': 'Jane Hill',
#    'place': 12},
#   {'team': 'Parkway North',
#    'time': '1:03.15',
#    'grade': 'JR',
#    'name': 'Mary Wolf-Slinkard',
#    'place': 13},
#   {'team': 'Savannah',
#    'time': '1:03.73',
#    'grade': 'JR',
#    'name': 'Reece Gould',
#    'place': 14},
#   {'team': 'Central (Springf',
#    'time': '1:04.22',
#    'grade': 'SR',
#    'name': 'Naomi Meng',
#    'place': 15},
#   {'team': 'Logan-Rogersvill',
#    'time': '1:04.49',
#    'grade': 'SR',
#    'name': 'Mya Kite',
#    'place': 16},
#   {'team': 'Washington',
#    'time': '1:04.79',
#    'grade': 'SO',
#    'name': 'Brooke Schoonover',
#    'place': 17},
#   {'team': 'Notre Dame de Si',
#    'time': '1:05.06',
#    'grade': 'SO',
#    'name': 'India Browning',
#    'place': 18},
#   {'team': "St. Teresa's Aca",
#    'time': '1:05.06',
#    'grade': 'SR',
#    'name': 'Addilyn Akers',
#    'place': 19},
#   {'team': 'STEAM Academy',
#    'time': '1:05.74',
#    'grade': 'SO',
#    'name': 'Alexis Stone',
#    'place': 20},
#   {'team': 'Lutheran St. Cha',
#    'time': '1:05.89',
#    'grade': 'SR',
#    'name': 'LaNiya Hackney',
#    'place': 21},
#   {'team': 'Grain Valley',
#    'time': '1:06.03',
#    'grade': 'JR',
#    'name': 'Emily Holzwarth',
#    'place': 22},
#   {'team': 'New Covenant Aca',
#    'time': '1:06.05',
#    'grade': 'SR',
#    'name': 'Natalie Block',
#    'place': 23},
#   {'team': 'Villa Duchesne',
#    'time': '1:06.74',
#    'grade': 'SR',
#    'name': 'Mia Crandall',
#    'place': 24},
#   {'team': 'Ladue Horton Wat',
#    'time': '1:06.90',
#    'grade': 'FR',
#    'name': 'Kaedyn Miller',
#    'place': 25},
#   {'team': 'Notre Dame Cape',
#    'time': '1:06.98',
#    'grade': 'SO',
#    'name': 'Kyra Langenstein',
#    'place': 26},
#   {'team': 'Savannah',
#    'time': '1:07.28',
#    'grade': 'JR',
#    'name': 'Meghan Piper',
#    'place': 27},
#   {'team': 'St. Dominic',
#    'time': '1:07.51',
#    'grade': 'SO',
#    'name': 'Elise Poulter',
#    'place': 28},
#   {'team': 'Smithville',
#    'time': '1:07.59',
#    'grade': 'SR',
#    'name': 'Isabel Sapp',
#    'place': 29},
#   {'team': 'Republic',
#    'time': '1:07.65',
#    'grade': 'FR',
#    'name': 'Amelia Beaver',
#    'place': 30},
#   {'team': 'Rockwood Summit',
#    'time': '1:07.73',
#    'grade': 'SR',
#    'name': 'Lillian Maginn',
#    'place': 31},
#   {'team': 'Hannibal',
#    'time': '1:07.94',
#    'grade': 'SR',
#    'name': 'Emily Groth',
#    'place': 32}],
#  'Event 11 Girls 100 Yard Breaststroke': [{'team': 'Visitation Acade',
#    'time': '1:05.35',
#    'grade': 'SR',
#    'name': 'Ashlyn Canale',
#    'place': 1},
#   {'team': 'Villa Duchesne',
#    'time': '1:06.10',
#    'grade': 'JR',
#    'name': 'Charlotte Brown',
#    'place': 2},
#   {'team': "St. Joseph's Aca",
#    'time': '1:06.52',
#    'grade': 'FR',
#    'name': 'Payton Robic',
#    'place': 3},
#   {'team': "St. Joseph's Aca",
#    'time': '1:07.38',
#    'grade': 'JR',
#    'name': 'Vienna Schindler',
#    'place': 4},
#   {'team': 'John Burroughs',
#    'time': '1:07.48',
#    'grade': 'SR',
#    'name': 'Jacqueline Hu',
#    'place': 5},
#   {'team': 'Ursuline Academy',
#    'time': '1:07.48',
#    'grade': 'SO',
#    'name': 'Kennedy Chrun',
#    'place': 6},
#   {'team': 'St. Charles West',
#    'time': '1:07.49',
#    'grade': 'SR',
#    'name': 'Stella Garrison',
#    'place': 7},
#   {'team': 'Notre Dame de Si',
#    'time': '1:09.02',
#    'grade': 'SO',
#    'name': 'Finley Glennon',
#    'place': 8},
#   {'team': 'Parkway Central',
#    'time': '1:09.57',
#    'grade': 'JR',
#    'name': 'Serena Huang',
#    'place': 9},
#   {'team': 'St. Pius X (Kans',
#    'time': '1:09.77',
#    'grade': 'SR',
#    'name': 'Alynah Tran',
#    'place': 10},
#   {'team': 'Glendale',
#    'time': '1:10.40',
#    'grade': 'SO',
#    'name': 'Jayli Cope',
#    'place': 11},
#   {'team': 'Webb City',
#    'time': '1:10.99',
#    'grade': 'SR',
#    'name': 'Camryn Klosterman',
#    'place': 12},
#   {'team': 'Parkway West',
#    'time': '1:11.47',
#    'grade': 'SR',
#    'name': 'Ava McLeod',
#    'place': 13},
#   {'team': 'Principia',
#    'time': '1:11.89',
#    'grade': 'FR',
#    'name': 'Sarah Lamb',
#    'place': 14},
#   {'team': 'Monett',
#    'time': '1:11.98',
#    'grade': 'SO',
#    'name': 'Emelia Rosebaugh',
#    'place': 15},
#   {'team': 'Hannibal',
#    'time': '1:12.89',
#    'grade': 'JR',
#    'name': 'Olivia Johnson',
#    'place': 16},
#   {'team': 'Marshfield',
#    'time': '1:12.89',
#    'grade': 'SR',
#    'name': 'Sofia Moncada-Harris',
#    'place': 17},
#   {'team': 'Villa Duchesne',
#    'time': '1:12.96',
#    'grade': 'JR',
#    'name': 'Audrey Qureshi',
#    'place': 18},
#   {'team': 'John Burroughs',
#    'time': '1:13.03',
#    'grade': 'FR',
#    'name': 'Alicia Williams',
#    'place': 19},
#   {'team': 'Pembroke Hill',
#    'time': '1:13.26',
#    'grade': 'JR',
#    'name': 'Colbie Hyde',
#    'place': 20},
#   {'team': 'Carl Junction',
#    'time': '1:13.30',
#    'grade': 'SO',
#    'name': 'Elsa Dogotch',
#    'place': 21},
#   {'team': 'Smithville',
#    'time': '1:13.38',
#    'grade': 'FR',
#    'name': 'Elliette Chambers',
#    'place': 22},
#   {'team': 'Greenwood',
#    'time': '1:13.49',
#    'grade': 'FR',
#    'name': 'Olyvia Beach',
#    'place': 23},
#   {'team': 'Republic',
#    'time': '1:13.82',
#    'grade': 'FR',
#    'name': 'Elise Replogle',
#    'place': 24},
#   {'team': 'St. Dominic',
#    'time': '1:13.92',
#    'grade': 'JR',
#    'name': 'Amelia Martin',
#    'place': 25},
#   {'team': 'Summit Christian',
#    'time': '1:14.03',
#    'grade': 'FR',
#    'name': 'Jillian Markley',
#    'place': 26},
#   {'team': 'Platte County',
#    'time': '1:14.33',
#    'grade': 'JR',
#    'name': 'Ashleigh Cruce',
#    'place': 27},
#   {'team': 'Parkway West',
#    'time': '1:14.50',
#    'grade': 'JR',
#    'name': 'Emily McLeod',
#    'place': 28},
#   {'team': 'Battle',
#    'time': '1:14.64',
#    'grade': 'SO',
#    'name': 'Lila Morris',
#    'place': 29},
#   {'team': 'Grain Valley',
#    'time': '1:14.80',
#    'grade': 'SR',
#    'name': 'Riley Wade',
#    'place': 30},
#   {'team': 'Monett',
#    'time': '1:14.93',
#    'grade': 'FR',
#    'name': 'Olivia Earnest',
#    'place': 31},
#   {'team': 'Parkway Central',
#    'time': '1:15.53',
#    'grade': 'SO',
#    'name': 'Victoria Knolhoff',
#    'place': 32}]}

# %%
# read relay events
r_events = {}
with open("./psych_res_relays.txt", "r") as times:
    lines = times.readlines()
    curr_evnt = ""
    for l in lines:
        if "EVENT NAME" in l:
            curr_evnt = l[12:len(l)-1]
            r_events[curr_evnt] = []
        else:
            as_list = l.split('\t')
            if as_list[0][0].isdigit():
                r_events[curr_evnt].append({
                    "event": " ".join(curr_evnt.split()[3:]), "time": as_list[0], "team": as_list[1], "place": int(as_list[2])})

# %%
r_events
# Out:
# {'Event 1 Girls 200 Yard Medley Relay': [{'event': '200 Yard Medley Relay',
#    'time': '1:46.01',
#    'team': "St. Joseph's Aca",
#    'place': 1},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:51.63',
#    'team': 'Pembroke Hill',
#    'place': 2},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:52.04',
#    'team': 'Visitation Acade',
#    'place': 3},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:53.36',
#    'team': 'Villa Duchesne',
#    'place': 4},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:53.81',
#    'team': 'Clayton',
#    'place': 5},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:54.14',
#    'team': 'John Burroughs',
#    'place': 6},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:55.81',
#    'team': 'Parkway West',
#    'place': 7},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:56.25',
#    'team': 'West Plains',
#    'place': 8},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:58.16',
#    'team': 'Monett',
#    'place': 9},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:58.52',
#    'team': "St. Teresa's Aca",
#    'place': 10},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:58.77',
#    'team': 'Notre Dame de Si',
#    'place': 11},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:59.35',
#    'team': 'Parkway Central',
#    'place': 12},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:59.55',
#    'team': 'Webb City',
#    'place': 13},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:59.63',
#    'team': 'Carl Junction',
#    'place': 14},
#   {'event': '200 Yard Medley Relay',
#    'time': '1:59.88',
#    'team': 'Ladue Horton Wat',
#    'place': 15},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:00.23',
#    'team': 'Glendale',
#    'place': 16},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:00.32',
#    'team': 'Ursuline Academy',
#    'place': 17},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:00.45',
#    'team': 'Louisiana',
#    'place': 18},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:00.54',
#    'team': 'Grain Valley',
#    'place': 19},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:00.83',
#    'team': 'Webster Groves',
#    'place': 20},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.24',
#    'team': 'Smithville',
#    'place': 21},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.35',
#    'team': 'Central (Springf',
#    'place': 22},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.37',
#    'team': 'Savannah',
#    'place': 23},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.47',
#    'team': 'Lutheran St. Cha',
#    'place': 24},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.50',
#    'team': 'Platte County',
#    'place': 25},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:01.67',
#    'team': 'Father Tolton Re',
#    'place': 26},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:02.36',
#    'team': 'Kearney',
#    'place': 27},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:02.49',
#    'team': 'Hannibal',
#    'place': 28},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:02.50',
#    'team': 'Marshfield',
#    'place': 29},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:02.65',
#    'team': 'St. Michael the',
#    'place': 30},
#   {'event': '200 Yard Medley Relay',
#    'time': '2:03.26',
#    'team': 'Ft. Zumwalt Sout',
#    'place': 31}],
#  'Event 2 Girls 200 Yard Freestyle': [],
#  'Event 3 Girls 200 Yard IM': [],
#  'Event 4 Girls 50 Yard Freestyle': [],
#  'Event 6 Girls 100 Yard Butterfly': [],
#  'Event 7 Girls 100 Yard Freestyle': [],
#  'Event 8 Girls 500 Yard Freestyle': [],
#  'Event 9 Girls 200 Yard Freestyle Relay': [{'event': '200 Yard Freestyle Relay',
#    'time': '2:03.48',
#    'team': 'Notre Dame Cape',
#    'place': 32},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:38.79',
#    'team': 'Central Cape Gir',
#    'place': 1},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:39.65',
#    'team': "St. Joseph's Aca",
#    'place': 2},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:40.48',
#    'team': 'Pembroke Hill',
#    'place': 3},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:41.32',
#    'team': "St. Teresa's Aca",
#    'place': 4},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:41.69',
#    'team': 'Parkway Central',
#    'place': 5},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:43.44',
#    'team': 'Visitation Acade',
#    'place': 6},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:43.93',
#    'team': 'West Plains',
#    'place': 7},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:45.15',
#    'team': 'Grain Valley',
#    'place': 8},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:45.40',
#    'team': 'Notre Dame de Si',
#    'place': 9},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:45.75',
#    'team': 'Clayton',
#    'place': 10},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:45.99',
#    'team': 'Parkway West',
#    'place': 11},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:46.05',
#    'team': 'Villa Duchesne',
#    'place': 12},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:46.19',
#    'team': 'Carl Junction',
#    'place': 13},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:46.30',
#    'team': 'Father Tolton Re',
#    'place': 14},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:46.50',
#    'team': 'St. Francis Borg',
#    'place': 15},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:46.87',
#    'team': 'St. Michael the',
#    'place': 16},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:47.03',
#    'team': 'Central (Springf',
#    'place': 17},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:47.10',
#    'team': 'Nevada',
#    'place': 18},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:47.49',
#    'team': 'Webb City',
#    'place': 19},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.02',
#    'team': 'Rockwood Summit',
#    'place': 20},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.18',
#    'team': 'Ladue Horton Wat',
#    'place': 21},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.20',
#    'team': 'Glendale',
#    'place': 22},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.28',
#    'team': 'John Burroughs',
#    'place': 23},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.32',
#    'team': 'Mehlville',
#    'place': 24},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.73',
#    'team': 'Logan-Rogersvill',
#    'place': 25},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.84',
#    'team': 'Louisiana',
#    'place': 26},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:48.84',
#    'team': 'Lutheran St. Cha',
#    'place': 27},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:49.02',
#    'team': 'Savannah',
#    'place': 28},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:49.15',
#    'team': 'Kearney',
#    'place': 29},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:49.27',
#    'team': 'Hannibal',
#    'place': 30},
#   {'event': '200 Yard Freestyle Relay',
#    'time': '1:49.32',
#    'team': 'Monett',
#    'place': 31}],
#  'Event 10 Girls 100 Yard Backstroke': [],
#  'Event 11 Girls 100 Yard Breaststroke': [],
#  'Event 12 Girls 400 Yard Freestyle Relay': [{'event': '400 Yard Freestyle Relay',
#    'time': '1:49.64',
#    'team': 'Webster Groves',
#    'place': 32},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:32.11',
#    'team': "St. Joseph's Aca",
#    'place': 1},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:36.29',
#    'team': 'Central Cape Gir',
#    'place': 2},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:41.55',
#    'team': 'Parkway Central',
#    'place': 3},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:41.88',
#    'team': 'Pembroke Hill',
#    'place': 4},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:43.33',
#    'team': 'Clayton',
#    'place': 5},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:43.84',
#    'team': "St. Teresa's Aca",
#    'place': 6},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:49.92',
#    'team': 'John Burroughs',
#    'place': 7},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:50.99',
#    'team': 'West Plains',
#    'place': 8},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:52.72',
#    'team': 'Father Tolton Re',
#    'place': 9},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:53.54',
#    'team': 'Grain Valley',
#    'place': 10},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:53.77',
#    'team': 'Notre Dame de Si',
#    'place': 11},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:54.35',
#    'team': 'Villa Duchesne',
#    'place': 12},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:55.20',
#    'team': 'Visitation Acade',
#    'place': 13},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:57.01',
#    'team': 'St. Francis Borg',
#    'place': 14},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:57.76',
#    'team': 'Lutheran St. Cha',
#    'place': 15},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:58.11',
#    'team': 'Ladue Horton Wat',
#    'place': 16},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:58.37',
#    'team': 'Monett',
#    'place': 17},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:58.82',
#    'team': 'Webster Groves',
#    'place': 18},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:58.86',
#    'team': 'St. Michael the',
#    'place': 19},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:59.00',
#    'team': 'Parkway West',
#    'place': 20},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '3:59.69',
#    'team': 'Webb City',
#    'place': 21},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:00.46',
#    'team': 'Carl Junction',
#    'place': 22},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:01.84',
#    'team': 'Rockwood Summit',
#    'place': 23},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:02.34',
#    'team': 'Kearney',
#    'place': 24},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:02.51',
#    'team': 'Nevada',
#    'place': 25},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:02.71',
#    'team': 'Glendale',
#    'place': 26},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:02.89',
#    'team': 'Central (Springf',
#    'place': 27},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:03.43',
#    'team': 'Savannah',
#    'place': 28},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:03.59',
#    'team': 'Parkway North',
#    'place': 29},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:04.01',
#    'team': 'Logan-Rogersvill',
#    'place': 30},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:05.12',
#    'team': 'Notre Dame Cape',
#    'place': 31},
#   {'event': '400 Yard Freestyle Relay',
#    'time': '4:05.41',
#    'team': 'Platte County',
#    'place': 32}]}

# %%
# score
school_scores = {}
school_events = {}
person_scores = {}
person_events = {}

scoring = [20,17,16,15,14,13,12,11,9,7,6,5,4,3,2,1]
relay_scoring = [40,34,32,30,28,26,24,22,18,14,12,10,8,6,4,2]

for event in i_events:
    for i, info in enumerate(i_events[event]):
        if i==len(scoring):
            break
        
        if info["team"] in school_scores:
            school_scores[info["team"]] += scoring[i]
            school_events[info["team"]].append(info)
        else:
            school_scores[info["team"]] = scoring[i]
            school_events[info["team"]] = [info]

        if info["name"] in person_scores:
            person_scores[info["name"]] += scoring[i]
            person_events[info["name"]].append(info)
        else:
            person_scores[info["name"]] = scoring[i]
            person_events[info["name"]] = [info]

for event in r_events:
    for i, info in enumerate(r_events[event]):
        if i==len(relay_scoring):
            break
        if info["team"] in school_scores:
            school_scores[info["team"]] += relay_scoring[i]
            school_events[info["team"]].append(info)
        else:
            school_scores[info["team"]] = relay_scoring[i]
            school_events[info["team"]] = [info]

# %%
top_10 = sorted(school_scores.items(), key=lambda x:x[1], reverse=True)[0:10]

for i, item in enumerate(top_10):
    print(i+1, ": ", item[1], ",\t", item[0], sep="")
# Out:
# 1: 301,	St. Joseph's Aca
# 2: 171,	Central Cape Gir
# 3: 160,	Pembroke Hill
# 4: 151,	Parkway Central
# 5: 144,	Clayton
# 6: 126,	Visitation Acade
# 7: 117,	Villa Duchesne
# 8: 98,	St. Teresa's Aca
# 9: 97,	West Plains
# 10: 89,	Father Tolton Re

# %%
sorted(person_scores.items(), key=lambda x:x[1], reverse=True)[0:5]
# Out:
# [('Anna-Grace Guenther', 40),
#  ('Charlotte Brown', 37),
#  ('Helena Tietjen', 37),
#  ('Sydney Ringwald', 37),
#  ('Ashlyn Canale', 37)]

# %%
for e in school_events['Parkway Central']:
    print(e)
# Out:
# {'team': 'Parkway Central', 'time': '25.04', 'grade': 'JR', 'name': 'Cecilia Tremont', 'place': 8}
# {'team': 'Parkway Central', 'time': '25.43', 'grade': 'SO', 'name': 'Kenadie Johnson', 'place': 12}
# {'team': 'Parkway Central', 'time': '57.71', 'grade': 'JR', 'name': 'Reese Anderson', 'place': 3}
# {'team': 'Parkway Central', 'time': '59.02', 'grade': 'JR', 'name': 'Serena Huang', 'place': 5}
# {'team': 'Parkway Central', 'time': '54.71', 'grade': 'JR', 'name': 'Cecilia Tremont', 'place': 6}
# {'team': 'Parkway Central', 'time': '56.89', 'grade': 'SO', 'name': 'Gabrielle Salmans', 'place': 16}
# {'team': 'Parkway Central', 'time': '5:12.36', 'grade': 'JR', 'name': 'Reese Anderson', 'place': 3}
# {'team': 'Parkway Central', 'time': '1:09.57', 'grade': 'JR', 'name': 'Serena Huang', 'place': 9}
# {'event': '200 Yard Medley Relay', 'time': '1:59.35', 'team': 'Parkway Central', 'place': 12}
# {'event': '200 Yard Freestyle Relay', 'time': '1:41.69', 'team': 'Parkway Central', 'place': 5}
# {'event': '400 Yard Freestyle Relay', 'time': '3:41.55', 'team': 'Parkway Central', 'place': 3}

# %%
# time for diving!

reader = PyPDF2.PdfReader('./c1 district diving.pdf')

# %%
len(reader.pages[0].extract_text().split('\n')[5].split())
# Out:
# 8

# %%
reader.pages[1].extract_text().split('\n')
# Out:
# ['2025 C1D2 MSHSAA Girls District Championship',
#  'Event Results',
#  'Girls Diving 11 Dives',
#  'Score Diver Name Rank Order Team Affiliation Pts',
#  '111421.00 Eiley Minich Parkway West',
#  '210370.60 Sarah Fields Parkway Central',
#  '3 9320.10 Gabriella Pupillo Parkway West',
#  '4 5301.40 Abigail Hirsch Ft. Zumwalt South',
#  '5 8295.15 Eliza Loveless Parkway West',
#  '6 7284.00 Natalie Bruins Parkway Central',
#  '7 2277.85 Samantha Walden Ft. Zumwalt East',
#  '8 4272.85 Shelbey Hoagland Ft. Zumwalt South',
#  '9 6271.10 Catherine Bowman Parkway West',
#  '10 3241.30 Caitlyn Gagnepain St. Dominic',
#  '11 1194.35 Savannah Richards Lutheran/Veritas',
#  'Mary Institute and Country Day School 2/15/2025 1:06:40 PM Page 1 of 1']

# %%
def breakup_long_diver_string(input_str):
    pattern = r'^(\d+)\s+(\d+)([A-Za-z]+)\s+([A-Za-z]+)\s+(.*?)\s+(\d+\.\d{2})\s+(\d+\.\d{2})\s+(\d+\.\d{2})$'

    match = re.match(pattern, input_str)

    if match:
        place = int(match.group(1))
        diving_order = int(match.group(2))
        diver_name = f"{match.group(3)} {match.group(4)}"
        school = match.group(5)
        prelims = float(match.group(6))
        semis = float(match.group(7))
        finals = float(match.group(8))
        
        return [place, diving_order, diver_name, school, prelims, semis, finals]
    else:
        return None

# %%
def breakup_short_diver_string(input_str):
    pattern = r'^(?:(\d+)\s+(\d{1,2})|(\d)(\d{1,2}))(\d{3}\.\d{2})\s+([A-Za-z]+\s[A-Za-z]+)\s+(.*)$'
    match = re.match(pattern, input_str)
    
    if not match:
        return None
    
    if match.group(1) is not None:
        place = int(match.group(1))
        diving_order = int(match.group(2))
    else:
        place = int(match.group(3))
        diving_order = int(match.group(4))
    
    score = float(match.group(5))
    diver_name = match.group(6)
    school = match.group(7)
    
    return [place, diving_order, score, diver_name, school]

# %%
def can_convert_to_float(value):
    try:
        float(value)
        return True
    except (ValueError, TypeError):
        return False

# %%
all_district_res = []

for page in reader.pages:
    lines = page.extract_text().split('\n')

    for i, line in enumerate(lines):
        if i<4 or i==len(lines)-1:
            continue
        line = line.replace('-', '')
        split_line = line.split()
        if can_convert_to_float(split_line[-1]):
            res = breakup_long_diver_string(line)
            if not res:
                if 'and DIVING' in line:
                    line = lines[i-1]+" "+line
                    res = breakup_long_diver_string(line)
                    if not res:
                        continue
                    all_district_res.append({'score': res[6], 'school': res[3], 'name': res[2], })
                else:
                    print(line, 'long')
                continue
            all_district_res.append({'score': res[6], 'school': res[3], 'name': res[2], })
        else:
            res = breakup_short_diver_string(line)
            if not res:
                print(line, 'short')
                continue
            all_district_res.append({'score': res[2], 'school': res[4], 'name': res[3]})
# Out:
# 6 5Addison Branch MONETT HIGH SCHOOL SWIMMING  short
# 11 1Addalyn Brownlee MONETT HIGH SCHOOL SWIMMING  short

# %%
all_district_res
# Out:
# [{'score': 361.55, 'school': 'Villa Duchesne', 'name': 'Hannah Ponciroli'},
#  {'score': 322.75, 'school': 'Poplar Bluff', 'name': 'Allison Williamson'},
#  {'score': 313.35, 'school': 'Webster Groves', 'name': 'Esme HinyardLash'},
#  {'score': 307.35, 'school': 'Visitation Academy', 'name': 'Clara Hugge'},
#  {'score': 306.8, 'school': 'Saint Joesphs Academy', 'name': 'Tatum Smiley'},
#  {'score': 299.05,
#   'school': 'Mehlville High School',
#   'name': 'Abigail Fisher'},
#  {'score': 298.55, 'school': 'Ursuline Academy', 'name': 'Grace Travers'},
#  {'score': 297.55,
#   'school': 'Saint Joesphs Academy',
#   'name': 'Carlye Bennett'},
#  {'score': 294.35, 'school': 'Saint Joesphs Academy', 'name': 'Tatum Schwent'},
#  {'score': 286.45,
#   'school': 'Saint Joesphs Academy',
#   'name': 'Avery Bueltmann'},
#  {'score': 273.35,
#   'school': 'Ladue Horton Watkins HS',
#   'name': 'Annabelle Lang'},
#  {'score': 421.0, 'school': 'Parkway West', 'name': 'Eiley Minich'},
#  {'score': 370.6, 'school': 'Parkway Central', 'name': 'Sarah Fields'},
#  {'score': 320.1, 'school': 'Parkway West', 'name': 'Gabriella Pupillo'},
#  {'score': 301.4, 'school': 'Ft. Zumwalt South', 'name': 'Abigail Hirsch'},
#  {'score': 295.15, 'school': 'Parkway West', 'name': 'Eliza Loveless'},
#  {'score': 284.0, 'school': 'Parkway Central', 'name': 'Natalie Bruins'},
#  {'score': 277.85, 'school': 'Ft. Zumwalt East', 'name': 'Samantha Walden'},
#  {'score': 272.85, 'school': 'Ft. Zumwalt South', 'name': 'Shelbey Hoagland'},
#  {'score': 271.1, 'school': 'Parkway West', 'name': 'Catherine Bowman'},
#  {'score': 241.3, 'school': 'St. Dominic', 'name': 'Caitlyn Gagnepain'},
#  {'score': 194.35, 'school': 'Lutheran/Veritas', 'name': 'Savannah Richards'},
#  {'score': 373.45, 'school': 'Kearney', 'name': 'Anna Williams'},
#  {'score': 313.55, 'school': 'St Teresas Academy', 'name': 'Ellie sweeny'},
#  {'score': 294.95,
#   'school': 'January St Teresas Academy',
#   'name': 'Molly kate'},
#  {'score': 286.95, 'school': 'St Teresas Academy', 'name': 'Grace Gunter'},
#  {'score': 283.05,
#   'school': 'Lincoln College Preparatory Academy',
#   'name': 'Evelyn Behrens'},
#  {'score': 278.6, 'school': 'Pembroke Hill', 'name': 'Elizabeth Lowe'},
#  {'score': 274.45, 'school': 'St Teresas Academy', 'name': 'Sydney Graham'},
#  {'score': 271.65, 'school': 'Pembroke Hill', 'name': 'Katherine Copaken'},
#  {'score': 257.65, 'school': 'Barstow High School', 'name': 'Allison Luetje'},
#  {'score': 218.25, 'school': 'Pembroke Hill', 'name': 'Evelyn Christopher'},
#  {'score': 212.6, 'school': 'Platte County', 'name': 'Thais Thompson'},
#  {'score': 423.5, 'school': 'Notre Dame de Sion', 'name': 'Naya Narciso'},
#  {'score': 393.2,
#   'school': 'Central High School',
#   'name': 'Journey Wildschuetz'},
#  {'score': 385.6, 'school': 'Notre Dame de Sion', 'name': 'Stella Henderson'},
#  {'score': 358.5, 'school': 'Greenwood', 'name': 'Sophia Sechler'},
#  {'score': 345.3, 'school': 'Notre Dame de Sion', 'name': 'Kate Sobba'},
#  {'score': 332.6, 'school': 'Belton High School', 'name': 'Emma Gillespie'},
#  {'score': 325.4, 'school': 'Notre Dame de Sion', 'name': 'Brooke Sobba'},
#  {'score': 250.45, 'school': 'Webb City', 'name': 'Kaedyn Lewis'},
#  {'score': 248.4, 'school': 'Sacred Heart School', 'name': 'Paige Diller'}]

# %%
top_16_divers = sorted(all_district_res, key=lambda x:x['score'], reverse=True)[0:16]
top_16_divers
# Out:
# [{'score': 423.5, 'school': 'Notre Dame de Sion', 'name': 'Naya Narciso'},
#  {'score': 421.0, 'school': 'Parkway West', 'name': 'Eiley Minich'},
#  {'score': 393.2,
#   'school': 'Central High School',
#   'name': 'Journey Wildschuetz'},
#  {'score': 385.6, 'school': 'Notre Dame de Sion', 'name': 'Stella Henderson'},
#  {'score': 373.45, 'school': 'Kearney', 'name': 'Anna Williams'},
#  {'score': 370.6, 'school': 'Parkway Central', 'name': 'Sarah Fields'},
#  {'score': 361.55, 'school': 'Villa Duchesne', 'name': 'Hannah Ponciroli'},
#  {'score': 358.5, 'school': 'Greenwood', 'name': 'Sophia Sechler'},
#  {'score': 345.3, 'school': 'Notre Dame de Sion', 'name': 'Kate Sobba'},
#  {'score': 332.6, 'school': 'Belton High School', 'name': 'Emma Gillespie'},
#  {'score': 325.4, 'school': 'Notre Dame de Sion', 'name': 'Brooke Sobba'},
#  {'score': 322.75, 'school': 'Poplar Bluff', 'name': 'Allison Williamson'},
#  {'score': 320.1, 'school': 'Parkway West', 'name': 'Gabriella Pupillo'},
#  {'score': 313.55, 'school': 'St Teresas Academy', 'name': 'Ellie sweeny'},
#  {'score': 313.35, 'school': 'Webster Groves', 'name': 'Esme HinyardLash'},
#  {'score': 307.35, 'school': 'Visitation Academy', 'name': 'Clara Hugge'}]

# %%
scoring = [20,17,16,15,14,13,12,11,9,7,6,5,4,3,2,1]

for i, info in enumerate(top_16_divers):
    info['place'] = i+1
    if info["school"] in school_scores:
        school_scores[info["school"]] += scoring[i]
        school_events[info["school"]].append(info)
    else:
        school_scores[info["school"]] = scoring[i]
        school_events[info["school"]] = [info]

# %%
new_top_10 = sorted(school_scores.items(), key=lambda x:x[1], reverse=True)[0:10]

for i, item in enumerate(new_top_10):
    print(i+1, ": ", item[1], ",\t", item[0], sep="")
# Out:
# 1: 301,	St. Joseph's Aca
# 2: 171,	Central Cape Gir
# 3: 164,	Parkway Central
# 4: 160,	Pembroke Hill
# 5: 144,	Clayton
# 6: 129,	Villa Duchesne
# 7: 126,	Visitation Acade
# 8: 98,	St. Teresa's Aca
# 9: 97,	West Plains
# 10: 89,	Parkway West

# %%
for e in school_events['Parkway Central']:
    print(e)
# Out:
# {'team': 'Parkway Central', 'time': '25.04', 'grade': 'JR', 'name': 'Cecilia Tremont', 'place': 8}
# {'team': 'Parkway Central', 'time': '25.43', 'grade': 'SO', 'name': 'Kenadie Johnson', 'place': 12}
# {'team': 'Parkway Central', 'time': '57.71', 'grade': 'JR', 'name': 'Reese Anderson', 'place': 3}
# {'team': 'Parkway Central', 'time': '59.02', 'grade': 'JR', 'name': 'Serena Huang', 'place': 5}
# {'team': 'Parkway Central', 'time': '54.71', 'grade': 'JR', 'name': 'Cecilia Tremont', 'place': 6}
# {'team': 'Parkway Central', 'time': '56.89', 'grade': 'SO', 'name': 'Gabrielle Salmans', 'place': 16}
# {'team': 'Parkway Central', 'time': '5:12.36', 'grade': 'JR', 'name': 'Reese Anderson', 'place': 3}
# {'team': 'Parkway Central', 'time': '1:09.57', 'grade': 'JR', 'name': 'Serena Huang', 'place': 9}
# {'event': '200 Yard Medley Relay', 'time': '1:59.35', 'team': 'Parkway Central', 'place': 12}
# {'event': '200 Yard Freestyle Relay', 'time': '1:41.69', 'team': 'Parkway Central', 'place': 5}
# {'event': '400 Yard Freestyle Relay', 'time': '3:41.55', 'team': 'Parkway Central', 'place': 3}
# {'score': 370.6, 'school': 'Parkway Central', 'name': 'Sarah Fields', 'place': 6}
